# %%
from chemper.mol_toolkits import mol_toolkit

# %%
mols = mol_toolkit.mols_from_mol2('MiniDrugBank_tripos.mol2')

# %%
for m in mols:
    print(m)
# Out:
# COC(=O)C1C(c2ccc(F)cc2)CC2CCC1N2C/C=C/I
# O=C(O)Cc1nn(Cc2nc3cc(C(F)(F)F)ccc3s2)c(=O)c2ccccc12
# O=C(O)CSCC(=O)NC1CCSC1=O
# CC1(C)SC2C(NC(=O)C(N=[N+]=[N-])c3ccccc3)C(=O)N2C1C(=O)O
# CC12CCC3C(CCC4CC(O)CCC43C)C1CC(Br)C2=O
# O=C1C2C3CCC(C3)C2C(=O)N1CC1CCCCC1CN1CCN(c2nsc3ccccc23)CC1
# C=CCN(C)CCCCCCOc1ccc2c(-c3ccc(Br)cc3)nsc2c1
# COC(=O)C1C(c2ccc(I)cc2)CC2CCC1N2CCCF
# C#CCCCn1c(Cc2cc(OC)c(OC)c(OC)c2Cl)nc2c(N)nc(F)nc21
# O=C(O)CC(O)CC(O)/C=C/c1c(C2CC2)nc2ccccc2c1-c1ccc(F)cc1
# O=C(O)C(S)Cc1ccc(I)cc1
# COc1cc2nccc(Oc3ccc(NC(=O)C4(C(=O)Nc5ccc(F)cc5)CC4)cc3)c2cc1OC
# C#CC(O)(/C=C/Cl)CC
# CC(C)CC(NC(=O)C(CCc1ccccc1)NC(=O)CN1CCOCC1)C(=O)NC(Cc1ccccc1)C(=O)NC(CC(C)C)C(=O)C1(C)CO1
# CNC(=O)C1OC(n2cnc3c(NCc4cccc(I)c4)ncnc32)C(O)C1O
# CC(=O)NC(Cc1cc(I)c(O)c(I)c1)C(=O)NCC(=O)O
# CC(=O)Nc1cccc(-n2c(=O)n(C3CC3)c(=O)c3c(Nc4ccc(I)cc4F)n(C)c(=O)c(C)c32)c1
# CC1=C(CO)C2=C(C)C3(CC3)C(C)(O)C(=O)C2=C1
# CCN(CC)C(=O)C1(c2ccccc2)CC1CN
# O=C1C2CCCCC2C(=O)N1CCCCN1CCN(c2nsc3ccccc23)CC1
# ...
