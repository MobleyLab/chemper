# %%
from copy import deepcopy
import time
from chemper.chemper_utils import get_full_path, create_tuples_for_clusters
from chemper.mol_toolkits.mol_toolkit import mols_from_mol2, Mol, HAS_OE, HAS_RDK
from chemper.smirksify import SMIRKSifier, print_smirks
import pickle as p

# %%
def parse_smarts_file(file_path):
    """

    Parameters
    ----------
    file_path: str
        relative path in chemper/data or absolute path

    Returns
    -------
    smirks_list: list of tuples (label, smirks)
        This is the ordered list of SMIRKS from the smarts file
        if a label is provided in the file then it is assigned, otherwise
        the indices from the file is used
    """
    fn = get_full_path(file_path)
    f = open(fn)
    lines = f.readlines()
    f.close()

    lines = [l.split() for l in lines]
    if len(lines[0]) > 1:
        return [(label, smirks) for smirks, label in lines]

    return [(str(i), l[0]) for i, l in enumerate(lines)]

# %%
def make_smarts_file(smirks_list, output_file):
    """
    Parameters
    ----------
    smirks_list: list of tuples
        smirks tuples have the form (label, smirks
    output_file: relative or absolute path
    """
    f = open(output_file, 'w')
    for label, smirks in smirks_list:
        f.write("%s %s\n" % (smirks, label))
    f.close()

# %%
def run_fragement(frag, mols, steps=1000):
    """

    Parameters
    ----------
    frag: str
        angle, bond, nonbond, proper_torsion
    mols: list of molecules
    steps: number of reducing steps

    Returns
    -------
    new_smirks_list: list of tuples
        Final list of tuples
    """
    print("Searching %s" % frag)

    # open and parse SMIRKS file
    smirks_list = parse_smarts_file('smarts_files/%s_smirks.smarts' % frag)

    # copy the molecules:
    current_mols = deepcopy(mols)

    # type molecules with these smirks:
    print("clustering molecules:")
    init = time.time()
    clusters = create_tuples_for_clusters(smirks_list, current_mols)
    end = time.time()
    print("Took %.3f minutes to type %i mols\n" % ((end-init)/60., len(mols)))

    # Try to make SMIRKS for these clusters:
    print("Creating initial SMIRKS...")
    init = time.time()
    create_frag = SMIRKSifier(current_mols, clusters, verbose=False, strict_smirks=False)
    end = time.time()
    print("generating smirksifier took %.3f minutes\n" % ((end-init)/60.))
    
    if not create_frag.checks:
        return None, create_frag

    print_smirks(create_frag.current_smirks)

    print("Reducing SMIRKS...")
    init = time.time()
    new_smirks_list = create_frag.reduce(steps)
    end = time.time()
    print("reducing SMIRKS took %.3f minutes\n" % ((end-init)/60.))

    return new_smirks_list, create_frag

# %%
# 1. load molecules
mol_file1 = 'MiniDrugBank_tripos.mol2'
mol_file2 = '/Users/bannanc/Desktop/baby_minidrugbank.mol2'
mol_file3 = "/Users/bannanc/gitHub/openforcefield/openforcefield/data/molecules/AlkEthOH_test_filt1_tripos.mol2"

mol_opts = [
    (mol_file1, 'minidrugbank'), (mol_file2, 'baby_mini_drugbank'), (mol_file3, 'alkethoh')
]

if HAS_OE:
    prefix = 'oe'
else:
    prefix = 'rdk'
    
for mol_file, mol_name in mol_opts:
    
    mols = list()
    for m in mols_from_mol2(mol_file):
        new_m = Mol(m)
        m.set_aromaticity_mdl()
        mols.append(m)

    # Loop over all fragment types
    fragments = ['nonbond', 'bond', 'angle', 'proper_torsion']
    n_steps = 1000
    smirksifiers = dict()
    smirks_lists = dict()

    for fragment in fragments:
        frag_smirks_list, frag_smirksifier = run_fragement(fragment, mols, steps=n_steps)
        smirksifiers[fragment] = frag_smirksifier
        smirks_lists[fragment] = frag_smirks_list
    
    p.dump((smirks_lists, smirksifiers), open('%s_%s.p' % (prefix, mol_name), 'wb'))
# Out:
# Searching nonbond
# clustering molecules:
# Took 0.122 minutes to type 363 mols
#
# Creating initial SMIRKS...
# WARNING!
#                       SMIRKSifier was not able to create SMIRKS for the provided
#                       clusters with 5 layers. Try increasing the number of layers
#                       or changing your clusters
#
# generating smirksifier took 7.281 minutes
#
# Searching bond
# clustering molecules:
# Took 0.282 minutes to type 363 mols
#
# Creating initial SMIRKS...
# WARNING!
#                       SMIRKSifier was not able to create SMIRKS for the provided
#                       clusters with 5 layers. Try increasing the number of layers
#                       or changing your clusters
#
# generating smirksifier took 12.971 minutes
#
# Searching angle
# clustering molecules:
# Took 0.244 minutes to type 363 mols
#
# Creating initial SMIRKS...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-6ba8a9151de3> in <module>()
#      28
#      29     for fragment in fragments:
# ---> 30         frag_smirks_list, frag_smirksifier = run_fragement(fragment, mols, steps=n_steps)
#      31         smirksifiers[fragment] = frag_smirksifier
#      32         smirks_lists[fragment] = frag_smirks_list
#
# <ipython-input-4-221eec8c000a> in run_fragement(frag, mols, steps)
#      32     print("Creating initial SMIRKS...")
#      33     init = time.time()
# ---> 34     create_frag = SMIRKSifier(current_mols, clusters, verbose=False, strict_smirks=False)
#      35     end = time.time()
#      36     print("generating smirksifier took %.3f minutes\n" % ((end-init)/60.))
#
# ~/gitHub/chemper/chemper/smirksify.py in __init__(self, molecules, cluster_list, max_layers, verbose, strict_smirks)
#     155
#     156         # make SMIRKS patterns for input clusters
# --> 157         self.current_smirks, self.layers = self.make_smirks(max_layers)
#     158         if self.verbose: print_smirks(self.current_smirks)
#     159         # check SMIRKS and save the matches to input clusters
#
# ~/gitHub/chemper/chemper/smirksify.py in make_smirks(self, max_layers)
#     198         while not checks and (layers < max_layers):
#     199             layers += 1
# --> 200             smirks_list = self._make_cluster_graphs(layers)
#     201             # store intermediate smirks
#     202             self.intermediate_smirks[layers] = smirks_list
#
# ~/gitHub/chemper/chemper/smirksify.py in _make_cluster_graphs(self, layers)
#     217         for label, smirks_atom_list in self.cluster_list:
#     218             # make a ClusterGraph for that label
# --> 219             graph = ClusterGraph(self.molecules, smirks_atom_list, layers)
#     220
#     221             # extract and save the SMIRKS for the cluster
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in __init__(self, mols, smirks_atoms_lists, layers)
#     408
#     409             for idx, mol in enumerate(temp_mols):
# --> 410                 self.add_mol(mol, smirks_atoms_lists[idx])
#     411
#     412     def as_smirks(self, compress=False):
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in add_mol(self, input_mol, smirks_atoms_list)
#     473             self._add_mol(mol, smirks_atoms_list[1:])
#     474         else:
# --> 475             self._add_mol(mol, smirks_atoms_list)
#     476
#     477         self.mols.append(mol)
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in _add_mol(self, mol, smirks_atoms_list)
#     692         for smirks_atoms in smirks_atoms_list:
#     693             atom_dict = dict()
# --> 694             sorted_smirks_atoms = self._symmetry_funct(mol, smirks_atoms)
#     695             for key, atom_index in enumerate(sorted_smirks_atoms, 1):
#     696                 atom_dict[atom_index] = key
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in _angle_symmetry(self, mol, smirks_atoms)
#     757             (self.atom_by_label[3], self.bond_by_label[(2,3)])
#     758         ]
# --> 759         pairs = self.find_pairs(atoms_and_bonds, storages)
#     760         order = [p[0].get_index() for p in sorted(pairs, key=lambda x: x[2].label)]
#     761         return tuple((order[0], smirks_atoms[1], order[1]))
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in find_pairs(self, atoms_and_bonds, storages)
#     642         for a_idx, (a, b) in atom_dict.items():
#     643             for s_idx, (sa, sb) in storage_dict.items():
# --> 644                 score = sa.compare_atom(a)
#     645                 score += sb.compare_bond(b)
#     646                 g.add_edge(a_idx,s_idx,weight=score+1)
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in compare_atom(self, atom)
#     240
#     241             score = 0
# --> 242             decs = self.make_atom_decorators(atom)
#     243
#     244             for ref in self.decorators:
#
# ~/gitHub/chemper/chemper/graphs/cluster_graph.py in make_atom_decorators(self, atom)
#     119                 'H%i' % atom.hydrogen_count(),
#     120                 'X%i' % atom.connectivity(),
# --> 121                 'x%i' % atom.ring_connectivity(),
#     122                 ring,
#     123                 charge
#
# ~/gitHub/chemper/chemper/mol_toolkits/cp_openeye.py in ring_connectivity(self)
#     252             number of bonds on the atom that are a part of a ring
#     253         """
# --> 254         return len([b for b in self.atom.GetBonds(oechem.OEBondIsInRing())])
#     255
#     256     def min_ring_size(self):
#
# KeyboardInterrupt:

# %% [markdown]
# # Reload molecule sets:

# %%
baby_mini_drugbank = p.load(open('baby_minidrugbank.p', 'rb'))
alkethoh = p.load(open('AlkEthOH.p', 'rb'))
minidrugbank = p.load(open('minidrugbank.p', 'rb'))
